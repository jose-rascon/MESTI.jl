# %% [markdown]
# ## Imports

# %%
using Pkg
Pkg.activate("~/.julia/environments/v1.12")

using MESTI, MPI, LinearAlgebra, SparseArrays
# Out:
#   Activating new project at `~/codes/apf/MESTI.jl/examples/learning/~/.julia/environments/v1.12`

# %% [markdown]
# lambda_0 =
